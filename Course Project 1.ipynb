# %% [markdown]
# Project Data Analysis: World Happiness Report

# %% [markdown]
# A. Importing, cleaning and numerical summaries

# %%
import pandas as pd

# %%
import numpy as np

# %%
data = pd.read_csv('data.csv')

# %%
data.head()
# Out:
#        Country  Happiness Rank  Happiness Score   Economy    Family    Health  \
# 0       Norway               1            7.537  1.616463  1.533524  0.796667
# 1      Denmark               2            7.522  1.482383  1.551122  0.792566
# 2      Iceland               3            7.504  1.480633  1.610574  0.833552
# 3  Switzerland               4            7.494  1.564980  1.516912  0.858131
# 4      Finland               5            7.469  1.443572  1.540247  0.809158
#
#     Freedom  Generosity  Corruption  Dystopia  Job Satisfaction  \
# 0  0.635423    0.362012    0.315964  2.277027              94.6
# 1  0.626007    0.355280    0.400770  2.313707              93.5
# 2  0.627163    0.475540    0.153527  2.322715              94.5
# 3  0.620071    0.290549    0.367007  2.276716              93.7
# 4  0.617951    0.245483    0.382612  2.430182              91.2
#
#            Region
# 0  Western Europe
# 1  Western Europe
# 2  Western Europe
# 3  Western Europe
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 12 columns):
# Country             153 non-null object
# Happiness Rank      153 non-null int64
# Happiness Score     153 non-null float64
# Economy             153 non-null float64
# Family              153 non-null float64
# Health              153 non-null float64
# Freedom             153 non-null float64
# Generosity          153 non-null float64
# Corruption          153 non-null float64
# Dystopia            153 non-null float64
# Job Satisfaction    151 non-null float64
# Region              153 non-null object
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.4+ KB

# %%
data.dtypes
# Out:
# Country              object
# Happiness Rank        int64
# Happiness Score     float64
# Economy             float64
# Family              float64
# Health              float64
# Freedom             float64
# Generosity          float64
# Corruption          float64
# Dystopia            float64
# Job Satisfaction    float64
# Region               object
# dtype: object

# %%
data.isnull().values.any()
# Out:
# True

# %%
data.isnull()
# Out:
#      Country  Happiness Rank  Happiness Score  Economy  Family  Health  \
# 0      False           False            False    False   False   False
# 1      False           False            False    False   False   False
# 2      False           False            False    False   False   False
# 3      False           False            False    False   False   False
# 4      False           False            False    False   False   False
# 5      False           False            False    False   False   False
# 6      False           False            False    False   False   False
# 7      False           False            False    False   False   False
# 8      False           False            False    False   False   False
# 9      False           False            False    False   False   False
# 10     False           False            False    False   False   False
# 11     False           False            False    False   False   False
# ...

# %%
data1 = data.dropna()

# %%
data1.isnull().any()
# Out:
# Country             False
# Happiness Rank      False
# Happiness Score     False
# Economy             False
# Family              False
# Health              False
# Freedom             False
# Generosity          False
# Corruption          False
# Dystopia            False
# Job Satisfaction    False
# Region              False
# dtype: bool

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 151 entries, 0 to 152
# Data columns (total 12 columns):
# Country             151 non-null object
# Happiness Rank      151 non-null int64
# Happiness Score     151 non-null float64
# Economy             151 non-null float64
# Family              151 non-null float64
# Health              151 non-null float64
# Freedom             151 non-null float64
# Generosity          151 non-null float64
# Corruption          151 non-null float64
# Dystopia            151 non-null float64
# Job Satisfaction    151 non-null float64
# Region              151 non-null object
# dtypes: float64(9), int64(1), object(2)
# memory usage: 15.3+ KB

# %%
data1.describe()
# Out:
#        Happiness Rank  Happiness Score     Economy      Family      Health  \
# count      151.000000       151.000000  151.000000  151.000000  151.000000
# mean        77.827815         5.357874    0.983895    1.190509    0.550794
# std         44.934732         1.132826    0.420955    0.286371    0.236116
# min          1.000000         2.693000    0.000000    0.000000    0.000000
# 25%         39.500000         4.505500    0.663371    1.042635    0.369866
# 50%         78.000000         5.279000    1.064578    1.253918    0.606042
# 75%        116.500000         6.101500    1.314879    1.418162    0.715975
# max        155.000000         7.537000    1.870766    1.610574    0.949492
#
#           Freedom  Generosity  Corruption    Dystopia  Job Satisfaction
# count  151.000000  151.000000  151.000000  151.000000        151.000000
# mean     0.409805    0.244914    0.123008    1.854910         75.209934
# std      0.150144    0.135236    0.102776    0.502189         12.962365
# ...

# %%
data1.set_index('Happiness Rank').head(10)
# Out:
#                     Country  Happiness Score   Economy    Family    Health  \
# Happiness Rank
# 1                    Norway            7.537  1.616463  1.533524  0.796667
# 2                   Denmark            7.522  1.482383  1.551122  0.792566
# 3                   Iceland            7.504  1.480633  1.610574  0.833552
# 4               Switzerland            7.494  1.564980  1.516912  0.858131
# 5                   Finland            7.469  1.443572  1.540247  0.809158
# 6               Netherlands            7.377  1.503945  1.428939  0.810696
# 7                    Canada            7.316  1.479204  1.481349  0.834558
# 8               New Zealand            7.314  1.405706  1.548195  0.816760
# 9                    Sweden            7.284  1.494387  1.478162  0.830875
# 10                Australia            7.284  1.484415  1.510042  0.843887
#
#                  Freedom  Generosity  Corruption  Dystopia  Job Satisfaction  \
# Happiness Rank
# ...

# %%
data1.set_index('Happiness Rank').tail(10)
# Out:
#                                  Country  Happiness Score   Economy    Family  \
# Happiness Rank
# 145                                Haiti            3.603  0.368610  0.640450
# 146                                Yemen            3.593  0.591683  0.935382
# 148                              Liberia            3.533  0.119042  0.872118
# 149                               Guinea            3.507  0.244550  0.791245
# 150                                 Togo            3.495  0.305445  0.431883
# 151                               Rwanda            3.471  0.368746  0.945707
# 152                                Syria            3.462  0.777153  0.396103
# 153                             Tanzania            3.349  0.511136  1.041990
# 154                              Burundi            2.905  0.091623  0.629794
# 155             Central African Republic            2.693  0.000000  0.000000
#
#                   Health   Freedom  Generosity  Corruption  Dystopia  \
# Happiness Rank
# ...

# %% [markdown]
# B.Indexing and grouping

# %%
data1.groupby('Region').size()
# Out:
# Region
# Africa            43
# Asia-Pacific      43
# Eastern Europe    21
# Europe             1
# Latin America     22
# North America      2
# Western Europe    19
# dtype: int64

# %%
data2 = data1.set_index('Region').drop('Europe')

# %%
datagroup = data2.groupby('Region')

# %%
datagroup.mean().sort_values('Happiness Score')
# Out:
#                 Happiness Rank  Happiness Score   Economy    Family    Health  \
# Region
# Africa              122.116279         4.254581  0.563714  0.970837  0.266773
# Asia-Pacific         78.325581         5.358326  1.059272  1.167791  0.608605
# Eastern Europe       70.619048         5.498952  1.178098  1.281235  0.681838
# Latin America        50.772727         5.957818  1.006981  1.290156  0.611009
# Western Europe       20.000000         6.880474  1.471893  1.485298  0.820159
# North America        10.500000         7.154500  1.512732  1.450635  0.804422
#
#                  Freedom  Generosity  Corruption  Dystopia  Job Satisfaction
# Region
# Africa          0.356791    0.211645    0.100776  1.784001         61.193023
# Asia-Pacific    0.429932    0.294002    0.148947  1.649736         77.834884
# Eastern Europe  0.311535    0.170583    0.050637  1.825065         77.628571
# Latin America   0.449222    0.210696    0.087764  2.301928         81.104545
# ...

# %%
filter = data2['Happiness Score']>6.0

# %%
data2[filter].groupby('Region').size()
# Out:
# Region
# Asia-Pacific      11
# Eastern Europe     1
# Latin America     13
# North America      2
# Western Europe    17
# dtype: int64

# %%
datagroup['Happiness Score'].max()
# Out:
# Region
# Africa            5.872
# Asia-Pacific      7.314
# Eastern Europe    6.098
# Latin America     7.079
# North America     7.316
# Western Europe    7.537
# Name: Happiness Score, dtype: float64

# %%
datagroup['Happiness Score'].min()
# Out:
# Region
# Africa            2.693
# Asia-Pacific      3.462
# Eastern Europe    4.644
# Latin America     3.603
# North America     6.993
# Western Europe    5.195
# Name: Happiness Score, dtype: float64

# %%
diff = datagroup['Happiness Score'].max()-datagroup['Happiness Score'].min()

# %%
diff
# Out:
# Region
# Africa            3.179
# Asia-Pacific      3.852
# Eastern Europe    1.454
# Latin America     3.476
# North America     0.323
# Western Europe    2.342
# Name: Happiness Score, dtype: float64

# %% [markdown]
# Africa has the largest range of happiness score

# %% [markdown]
# C. Bar plot of the Happiness Score

# %%
countryindex = data1.set_index('Country').head(10)

# %%
value = countryindex[0:10]['Happiness Score']

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
bar_plot = value.plot.barh(title = "Top 10 happiest country in the world")
plt.xlim(0,8)
bar_plot.set_xlable('Score')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-200-82b15a52f023> in <module>()
#       1 bar_plot = value.plot.barh(title = "Top 10 happiest country in the world")
#       2 plt.xlim(0,8)
# ----> 3 bar_plot.set_xlable('Score')
#
# AttributeError: 'AxesSubplot' object has no attribute 'set_xlable'

# %%
df = countryindex.drop(['Job Satisfaction','Happiness Rank','Happiness Score'],axis =1)

# %%
df.plot.barh(stacked=True)

# %%
a = data1[data1['Region']=='Africa']

# %%
b = a.set_index('Country')

# %%
df2 = b.drop(['Job Satisfaction','Happiness Rank','Happiness Score'],axis =1)

# %%
df2.plot.barh(stacked=True,figsize=(20,20))

# %%
c = data1['Job Satisfaction']

# %%
c.plot.hist(color = 'pink',edgecolor = 'black' )
plt.xlim(40,100)
# Out:
# (40, 100)

# %%
import seaborn as sns

# %%
d = data1.drop(['Happiness Rank'],axis=1)

# %%
sns.pairplot(d)

# %%
sns.pairplot(d,kind='reg')

# %% [markdown]
# Happiness Score has the highest correlation with Economy

# %% [markdown]
# Probabilities

# %% [markdown]
# First, we calculate the total number of countries with a Happiness Score above 6.0

# %%
total_hs6 = data1[data1['Happiness Score']> 6.0]

# %% [markdown]
# Then we calculate the total number of countries with Happiness Score above 6.0 and from Western Europe

# %%
total_hs6w = total_hs6[total_hs6['Region']=='Western Europe']

# %%
probability = len(total_hs6w)/len(total_hs6)

# %%
probability
# Out:
# 0.38636363636363635

# %%
len(data1)
# Out:
# 151

# %%
len(set(data1['Region']))
# Out:
# 7

# %%
data1.Region.value_counts()
# Out:
# Africa            43
# Asia-Pacific      43
# Latin America     22
# Eastern Europe    21
# Western Europe    19
# North America      2
# Europe             1
# Name: Region, dtype: int64

# %%
index = data1['Country']

# %%
columns =['Africa','Asia-Pacific','Eastern Europe','Latin America','Western Europe','North America','Europe']

# %%
data2 = data1.set_index('Country')

# %%
a = []
for x in index:
    if data2.Region[x]=='Africa': 
        a.append(1)
    else:
        a.append(0)
b = []
for x in index:
    if data2.Region[x]=='Asia-Pacific': 
        b.append(1)
    else:
        b.append(0)
c = []
for x in index:
    if data2.Region[x]=='Latin America':
        c.append(1)
    else:
        c.append(0)
d = []
for x in index:
    if data2.Region[x]=='Eastern Europe':
        d.append(1)
    else:
        d.append(0)
e = []
for x in index:
    if data2.Region[x]=='Western Europe':
        e.append(1)
    else:
        e.append(0)
f = []
for x in index:
    if data2.Region[x]=='North America':
        f.append(1)
    else:
        f.append(0)
g = []
for x in index:
    if data2.Region[x]=='Europe':
        g.append(1)
    else:
        g.append(0)

# %%
matrix = np.column_stack((a,b,c,d,e,f,g))
